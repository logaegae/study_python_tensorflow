# %% [markdown]
# # 베스트 모델 만들기 - 와인 사례
# ## 이진 분류
# ## 베스트 모델 업데이트하기

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# seed 값 설정
seed = 0
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# 데이터 입력
df_pre = pd.read_csv('dataset/wine.csv', header=None)
df = df_pre.sample(frac=1)
dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %%
# 모델 설정
model = Sequential([
    Dense(30, input_dim=12, activation='relu'),
    Dense(12, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')
]) 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 30)                390
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                372
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 875
# Trainable params: 875
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 컴파일 
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# 모델 저장 폴더 설정
import os
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

# %%
# 모델 저장 조건 설정
modelpath = MODEL_DIR + "best{epoch:03d}-{val_loss:.4f}.hdf5"

# checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1)
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)

# %%
# 모델 실행 및 저장
model.fit(X, Y, validation_split=0.2, epochs=200, batch_size=200, 
          verbose=0, callbacks=[checkpointer])
# Out:
# Epoch 00001: val_loss improved from inf to 0.28590, saving model to ./model/best001-0.2859.hdf5
#
# Epoch 00002: val_loss improved from 0.28590 to 0.24853, saving model to ./model/best002-0.2485.hdf5
#
# Epoch 00003: val_loss improved from 0.24853 to 0.22860, saving model to ./model/best003-0.2286.hdf5
#
# Epoch 00004: val_loss improved from 0.22860 to 0.20676, saving model to ./model/best004-0.2068.hdf5
#
# Epoch 00005: val_loss improved from 0.20676 to 0.19840, saving model to ./model/best005-0.1984.hdf5
#
# Epoch 00006: val_loss improved from 0.19840 to 0.19330, saving model to ./model/best006-0.1933.hdf5
#
# Epoch 00007: val_loss improved from 0.19330 to 0.19187, saving model to ./model/best007-0.1919.hdf5
#
# Epoch 00008: val_loss improved from 0.19187 to 0.18981, saving model to ./model/best008-0.1898.hdf5
#
# Epoch 00009: val_loss improved from 0.18981 to 0.18607, saving model to ./model/best009-0.1861.hdf5
#
# Epoch 00010: val_loss improved from 0.18607 to 0.18398, saving model to ./model/best010-0.1840.hdf5
#
# Epoch 00011: val_loss did not improve from 0.18398
#
# Epoch 00012: val_loss improved from 0.18398 to 0.17973, saving model to ./model/best012-0.1797.hdf5
#
# Epoch 00013: val_loss improved from 0.17973 to 0.17710, saving model to ./model/best013-0.1771.hdf5
#
# Epoch 00014: val_loss improved from 0.17710 to 0.17524, saving model to ./model/best014-0.1752.hdf5
#
# Epoch 00015: val_loss improved from 0.17524 to 0.17079, saving model to ./model/best015-0.1708.hdf5
#
# Epoch 00016: val_loss improved from 0.17079 to 0.16815, saving model to ./model/best016-0.1682.hdf5
#
# Epoch 00017: val_loss did not improve from 0.16815
#
# Epoch 00018: val_loss improved from 0.16815 to 0.16030, saving model to ./model/best018-0.1603.hdf5
#
# Epoch 00019: val_loss improved from 0.16030 to 0.15630, saving model to ./model/best019-0.1563.hdf5
#
# Epoch 00020: val_loss improved from 0.15630 to 0.15403, saving model to ./model/best020-0.1540.hdf5
#
# Epoch 00021: val_loss did not improve from 0.15403
#
# Epoch 00022: val_loss did not improve from 0.15403
#
# Epoch 00023: val_loss improved from 0.15403 to 0.14265, saving model to ./model/best023-0.1427.hdf5
#
# Epoch 00024: val_loss improved from 0.14265 to 0.13955, saving model to ./model/best024-0.1395.hdf5
#
# Epoch 00025: val_loss did not improve from 0.13955
#
# Epoch 00026: val_loss improved from 0.13955 to 0.13380, saving model to ./model/best026-0.1338.hdf5
#
# Epoch 00027: val_loss improved from 0.13380 to 0.13148, saving model to ./model/best027-0.1315.hdf5
#
# Epoch 00028: val_loss improved from 0.13148 to 0.12952, saving model to ./model/best028-0.1295.hdf5
#
# Epoch 00029: val_loss did not improve from 0.12952
#
# Epoch 00030: val_loss improved from 0.12952 to 0.12376, saving model to ./model/best030-0.1238.hdf5
#
# Epoch 00031: val_loss improved from 0.12376 to 0.11945, saving model to ./model/best031-0.1195.hdf5
#
# Epoch 00032: val_loss improved from 0.11945 to 0.11679, saving model to ./model/best032-0.1168.hdf5
#
# Epoch 00033: val_loss did not improve from 0.11679
#
# Epoch 00034: val_loss did not improve from 0.11679
#
# Epoch 00035: val_loss did not improve from 0.11679
#
# Epoch 00036: val_loss improved from 0.11679 to 0.10979, saving model to ./model/best036-0.1098.hdf5
#
# Epoch 00037: val_loss improved from 0.10979 to 0.10868, saving model to ./model/best037-0.1087.hdf5
#
# Epoch 00038: val_loss improved from 0.10868 to 0.10467, saving model to ./model/best038-0.1047.hdf5
#
# Epoch 00039: val_loss improved from 0.10467 to 0.10242, saving model to ./model/best039-0.1024.hdf5
#
# Epoch 00040: val_loss did not improve from 0.10242
#
# Epoch 00041: val_loss improved from 0.10242 to 0.09924, saving model to ./model/best041-0.0992.hdf5
#
# Epoch 00042: val_loss did not improve from 0.09924
#
# Epoch 00043: val_loss improved from 0.09924 to 0.09720, saving model to ./model/best043-0.0972.hdf5
#
# Epoch 00044: val_loss did not improve from 0.09720
#
# Epoch 00045: val_loss improved from 0.09720 to 0.09608, saving model to ./model/best045-0.0961.hdf5
#
# Epoch 00046: val_loss improved from 0.09608 to 0.09435, saving model to ./model/best046-0.0943.hdf5
#
# Epoch 00047: val_loss improved from 0.09435 to 0.09235, saving model to ./model/best047-0.0923.hdf5
#
# Epoch 00048: val_loss improved from 0.09235 to 0.09032, saving model to ./model/best048-0.0903.hdf5
#
# Epoch 00049: val_loss improved from 0.09032 to 0.08793, saving model to ./model/best049-0.0879.hdf5
#
# Epoch 00050: val_loss did not improve from 0.08793
#
# Epoch 00051: val_loss improved from 0.08793 to 0.08740, saving model to ./model/best051-0.0874.hdf5
#
# Epoch 00052: val_loss did not improve from 0.08740
#
# Epoch 00053: val_loss improved from 0.08740 to 0.08306, saving model to ./model/best053-0.0831.hdf5
#
# Epoch 00054: val_loss did not improve from 0.08306
#
# Epoch 00055: val_loss did not improve from 0.08306
#
# Epoch 00056: val_loss did not improve from 0.08306
#
# Epoch 00057: val_loss improved from 0.08306 to 0.08107, saving model to ./model/best057-0.0811.hdf5
#
# Epoch 00058: val_loss improved from 0.08107 to 0.07977, saving model to ./model/best058-0.0798.hdf5
#
# Epoch 00059: val_loss improved from 0.07977 to 0.07913, saving model to ./model/best059-0.0791.hdf5
#
# Epoch 00060: val_loss improved from 0.07913 to 0.07800, saving model to ./model/best060-0.0780.hdf5
#
# Epoch 00061: val_loss did not improve from 0.07800
#
# Epoch 00062: val_loss did not improve from 0.07800
#
# Epoch 00063: val_loss improved from 0.07800 to 0.07595, saving model to ./model/best063-0.0759.hdf5
#
# Epoch 00064: val_loss did not improve from 0.07595
#
# Epoch 00065: val_loss did not improve from 0.07595
#
# Epoch 00066: val_loss improved from 0.07595 to 0.07455, saving model to ./model/best066-0.0745.hdf5
#
# Epoch 00067: val_loss did not improve from 0.07455
#
# Epoch 00068: val_loss improved from 0.07455 to 0.07322, saving model to ./model/best068-0.0732.hdf5
#
# Epoch 00069: val_loss improved from 0.07322 to 0.07148, saving model to ./model/best069-0.0715.hdf5
#
# Epoch 00070: val_loss improved from 0.07148 to 0.07125, saving model to ./model/best070-0.0712.hdf5
#
# Epoch 00071: val_loss did not improve from 0.07125
#
# Epoch 00072: val_loss did not improve from 0.07125
#
# Epoch 00073: val_loss improved from 0.07125 to 0.07049, saving model to ./model/best073-0.0705.hdf5
#
# Epoch 00074: val_loss improved from 0.07049 to 0.06917, saving model to ./model/best074-0.0692.hdf5
#
# Epoch 00075: val_loss did not improve from 0.06917
#
# Epoch 00076: val_loss improved from 0.06917 to 0.06872, saving model to ./model/best076-0.0687.hdf5
#
# Epoch 00077: val_loss did not improve from 0.06872
#
# Epoch 00078: val_loss improved from 0.06872 to 0.06859, saving model to ./model/best078-0.0686.hdf5
#
# Epoch 00079: val_loss did not improve from 0.06859
#
# Epoch 00080: val_loss improved from 0.06859 to 0.06603, saving model to ./model/best080-0.0660.hdf5
#
# Epoch 00081: val_loss did not improve from 0.06603
#
# Epoch 00082: val_loss did not improve from 0.06603
#
# Epoch 00083: val_loss improved from 0.06603 to 0.06493, saving model to ./model/best083-0.0649.hdf5
#
# Epoch 00084: val_loss did not improve from 0.06493
#
# Epoch 00085: val_loss did not improve from 0.06493
#
# Epoch 00086: val_loss did not improve from 0.06493
#
# Epoch 00087: val_loss did not improve from 0.06493
#
# Epoch 00088: val_loss did not improve from 0.06493
#
# Epoch 00089: val_loss improved from 0.06493 to 0.06286, saving model to ./model/best089-0.0629.hdf5
#
# Epoch 00090: val_loss did not improve from 0.06286
#
# Epoch 00091: val_loss did not improve from 0.06286
#
# Epoch 00092: val_loss did not improve from 0.06286
#
# Epoch 00093: val_loss did not improve from 0.06286
#
# Epoch 00094: val_loss improved from 0.06286 to 0.05956, saving model to ./model/best094-0.0596.hdf5
#
# Epoch 00095: val_loss did not improve from 0.05956
#
# Epoch 00096: val_loss did not improve from 0.05956
#
# Epoch 00097: val_loss did not improve from 0.05956
#
# Epoch 00098: val_loss did not improve from 0.05956
#
# Epoch 00099: val_loss improved from 0.05956 to 0.05891, saving model to ./model/best099-0.0589.hdf5
#
# Epoch 00100: val_loss did not improve from 0.05891
#
# Epoch 00101: val_loss improved from 0.05891 to 0.05704, saving model to ./model/best101-0.0570.hdf5
#
# Epoch 00102: val_loss did not improve from 0.05704
#
# Epoch 00103: val_loss did not improve from 0.05704
# Epoch 00104: val_loss did not improve from 0.05704
#
# Epoch 00105: val_loss did not improve from 0.05704
#
# Epoch 00106: val_loss did not improve from 0.05704
#
# Epoch 00107: val_loss improved from 0.05704 to 0.05673, saving model to ./model/best107-0.0567.hdf5
#
# Epoch 00108: val_loss improved from 0.05673 to 0.05664, saving model to ./model/best108-0.0566.hdf5
#
# Epoch 00109: val_loss did not improve from 0.05664
#
# Epoch 00110: val_loss did not improve from 0.05664
#
# Epoch 00111: val_loss did not improve from 0.05664
#
# Epoch 00112: val_loss improved from 0.05664 to 0.05564, saving model to ./model/best112-0.0556.hdf5
#
# Epoch 00113: val_loss did not improve from 0.05564
#
# Epoch 00114: val_loss improved from 0.05564 to 0.05521, saving model to ./model/best114-0.0552.hdf5
#
# Epoch 00115: val_loss did not improve from 0.05521
#
# Epoch 00116: val_loss did not improve from 0.05521
#
# Epoch 00117: val_loss did not improve from 0.05521
#
# Epoch 00118: val_loss did not improve from 0.05521
#
# Epoch 00119: val_loss did not improve from 0.05521
#
# Epoch 00120: val_loss did not improve from 0.05521
#
# Epoch 00121: val_loss improved from 0.05521 to 0.05518, saving model to ./model/best121-0.0552.hdf5
#
# Epoch 00122: val_loss did not improve from 0.05518
#
# Epoch 00123: val_loss improved from 0.05518 to 0.05482, saving model to ./model/best123-0.0548.hdf5
#
# Epoch 00124: val_loss did not improve from 0.05482
#
# Epoch 00125: val_loss did not improve from 0.05482
#
# Epoch 00126: val_loss did not improve from 0.05482
#
# Epoch 00127: val_loss did not improve from 0.05482
#
# Epoch 00128: val_loss did not improve from 0.05482
#
# Epoch 00129: val_loss did not improve from 0.05482
#
# Epoch 00130: val_loss did not improve from 0.05482
#
# Epoch 00131: val_loss improved from 0.05482 to 0.05361, saving model to ./model/best131-0.0536.hdf5
#
# Epoch 00132: val_loss did not improve from 0.05361
#
# Epoch 00133: val_loss did not improve from 0.05361
#
# Epoch 00134: val_loss did not improve from 0.05361
#
# Epoch 00135: val_loss did not improve from 0.05361
#
# Epoch 00136: val_loss did not improve from 0.05361
#
# Epoch 00137: val_loss did not improve from 0.05361
#
# Epoch 00138: val_loss did not improve from 0.05361
#
# Epoch 00139: val_loss improved from 0.05361 to 0.05271, saving model to ./model/best139-0.0527.hdf5
#
# Epoch 00140: val_loss did not improve from 0.05271
#
# Epoch 00141: val_loss did not improve from 0.05271
#
# Epoch 00142: val_loss did not improve from 0.05271
#
# Epoch 00143: val_loss did not improve from 0.05271
#
# Epoch 00144: val_loss did not improve from 0.05271
#
# Epoch 00145: val_loss did not improve from 0.05271
#
# Epoch 00146: val_loss did not improve from 0.05271
#
# Epoch 00147: val_loss did not improve from 0.05271
#
# Epoch 00148: val_loss did not improve from 0.05271
#
# Epoch 00149: val_loss did not improve from 0.05271
#
# Epoch 00150: val_loss did not improve from 0.05271
#
# Epoch 00151: val_loss did not improve from 0.05271
#
# Epoch 00152: val_loss did not improve from 0.05271
#
# Epoch 00153: val_loss did not improve from 0.05271
#
# Epoch 00154: val_loss did not improve from 0.05271
#
# Epoch 00155: val_loss did not improve from 0.05271
#
# Epoch 00156: val_loss did not improve from 0.05271
#
# Epoch 00157: val_loss did not improve from 0.05271
#
# Epoch 00158: val_loss did not improve from 0.05271
#
# Epoch 00159: val_loss did not improve from 0.05271
#
# Epoch 00160: val_loss did not improve from 0.05271
#
# Epoch 00161: val_loss did not improve from 0.05271
#
# Epoch 00162: val_loss did not improve from 0.05271
#
# Epoch 00163: val_loss did not improve from 0.05271
#
# Epoch 00164: val_loss did not improve from 0.05271
#
# Epoch 00165: val_loss did not improve from 0.05271
#
# Epoch 00166: val_loss did not improve from 0.05271
#
# Epoch 00167: val_loss did not improve from 0.05271
#
# Epoch 00168: val_loss did not improve from 0.05271
#
# Epoch 00169: val_loss did not improve from 0.05271
#
# Epoch 00170: val_loss did not improve from 0.05271
#
# Epoch 00171: val_loss did not improve from 0.05271
#
# Epoch 00172: val_loss did not improve from 0.05271
#
# Epoch 00173: val_loss did not improve from 0.05271
#
# Epoch 00174: val_loss did not improve from 0.05271
#
# Epoch 00175: val_loss did not improve from 0.05271
#
# Epoch 00176: val_loss did not improve from 0.05271
#
# Epoch 00177: val_loss did not improve from 0.05271
#
# Epoch 00178: val_loss did not improve from 0.05271
#
# Epoch 00179: val_loss did not improve from 0.05271
#
# Epoch 00180: val_loss did not improve from 0.05271
#
# Epoch 00181: val_loss did not improve from 0.05271
#
# Epoch 00182: val_loss did not improve from 0.05271
#
# Epoch 00183: val_loss did not improve from 0.05271
#
# Epoch 00184: val_loss did not improve from 0.05271
#
# Epoch 00185: val_loss did not improve from 0.05271
#
# Epoch 00186: val_loss did not improve from 0.05271
#
# Epoch 00187: val_loss did not improve from 0.05271
#
# Epoch 00188: val_loss did not improve from 0.05271
#
# Epoch 00189: val_loss did not improve from 0.05271
#
# Epoch 00190: val_loss did not improve from 0.05271
#
# Epoch 00191: val_loss did not improve from 0.05271
#
# Epoch 00192: val_loss did not improve from 0.05271
#
# Epoch 00193: val_loss did not improve from 0.05271
#
# Epoch 00194: val_loss did not improve from 0.05271
#
# Epoch 00195: val_loss did not improve from 0.05271
#
# Epoch 00196: val_loss did not improve from 0.05271
#
# Epoch 00197: val_loss did not improve from 0.05271
#
# Epoch 00198: val_loss did not improve from 0.05271
#
# Epoch 00199: val_loss did not improve from 0.05271
#
# Epoch 00200: val_loss did not improve from 0.05271

# %%
del model

# %%
from tensorflow.keras.models import load_model
model = load_model('model/best139-0.0527.hdf5')

# %%
# 베스트 모델의 결과 출력 
print("\n Accuracy: %.4f" % (model.evaluate(X, Y, verbose=2)[1]))
# Out:
# 6497/1 - 0s - loss: 0.0339 - accuracy: 0.9858
#
#  Accuracy: 0.9858
